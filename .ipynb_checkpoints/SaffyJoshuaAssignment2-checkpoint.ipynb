# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %% [markdown]
# Hello friends.

# %%
diabetes_bunch = load_diabetes()

diabetes_progression = pd.DataFrame(diabetes_bunch.target, columns = ["disease progression"])
diabetes_df = pd.DataFrame(diabetes_bunch.data, columns=diabetes_bunch.feature_names)
diabetes_df.head(5)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
diabetes_progression.head(5)
# Out:
#    disease progression
# 0                151.0
# 1                 75.0
# 2                141.0
# 3                206.0
# 4                135.0

# %%
diabetes_df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260974e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324879e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947634e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243323e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335990e-01  1.356118e-01

# %%
diabetes_df.dtypes
# Out:
# age    float64
# sex    float64
# bmi    float64
# bp     float64
# s1     float64
# s2     float64
# s3     float64
# s4     float64
# s5     float64
# s6     float64
# dtype: object

# %%
for column in range(0, len(diabetes_df.columns)):
    plt.figure(column)
    plt.hist(diabetes_df.iloc[:,column])
    plt.xlabel(diabetes_df.columns[column])

# %%
seaborn.heatmap(diabetes_df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Just from eyeballing the heat map, it looks like the pairs of correlated values are (s3, s4), (s1, s2), (s4, s2).  By getting rid of s4 and s2, we can remove the correlation problem from the model.

# %%
diabetes_df = diabetes_df.drop(columns = ['s4','s2'])

# %%
seaborn.heatmap(diabetes_df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
seaborn.pairplot(diabetes_df.corr())

# %%
diabetes_test, diabetes_train = train_test_split(diabetes_df, test_size = .2)
progression_test, progression_train = train_test_split(diabetes_progression, test_size = .2)

# %%
print( 
    diabetes_test.shape,
    diabetes_train.shape,
    progression_test.shape,
    progression_train.shape,
    )
# Out:
# (353, 8) (89, 8) (353, 1) (89, 1)

# %%
#diabetes_test = diabetes_test.transpose
#diabetes_train = diabetes_train.transpose
#progression_test = progression_test.transpose
#progression_train = progression_train.transpose

# %%
linear_model = LinearRegression(fit_intercept = True).fit(diabetes_train, progression_train)

# %%
tree_model = DecisionTreeRegressor().fit(diabetes_train,progression_train)

# %%
forest_model = RandomForestRegressor().fit(diabetes_train, progression_train)
# Out:
# <ipython-input-155-f7207cb34080>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest_model = RandomForestRegressor().fit(diabetes_train, progression_train)

# %%
tree_prediction = tree_model.predict(diabetes_test)
forest_prediction = forest_model.predict(diabetes_test)

# %%
def printResults(model_name, model):
    prediction = model.predict(diabetes_test)
    val_score = cross_val_score(model, diabetes_train, y = progression_train)
    print(model_name)
    print("Mean Val Score: ", np.mean(val_score))
    print("Std Dev Val Score: ", np.std(val_score))
    print("R Squared: ", model.score(diabetes_test, progression_test))
    print("RMSE: ", mean_squared_error(prediction, progression_test, squared = False))
    print("")

# %%
printResults("Linear", linear_model)
printResults("Tree", tree_model)
printResults("Forest", forest_model)
# Out:
# Linear
# Mean Val Score:  -0.08645365821180655
# Std Dev Val Score:  0.19477404665312822
# R Squared:  -0.14788514663341146
# RMSE:  83.33620914013083
#
# Tree
# Mean Val Score:  -1.1961610137144314
# Std Dev Val Score:  0.8180796223493523
# R Squared:  -0.8233841757138536
# RMSE:  105.03247845188193
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# Forest
# Mean Val Score:  -0.14920160385950854
# Std Dev Val Score:  0.2512030791339876
# R Squared:  -0.17970717997858232
# RMSE:  84.48344877043851
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
